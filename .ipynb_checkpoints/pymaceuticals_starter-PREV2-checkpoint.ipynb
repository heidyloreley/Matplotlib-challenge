# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# ## Dependencies and starter code

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata = "Mouse_metadata.csv"
study_results = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# %%
# Combine the data into a single dataset --> MERGE tables into 1 dataframe

mouseStudy = pd.merge(mouse_metadata,study_results,how="left",on=["Mouse ID","Mouse ID"])
mouseStudy
#mouseStudy.dtypes
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %% [markdown]
# ## Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume 
# for each regimen

# 1. --> GROUPBY Regimen / Drug Regimen is my Index
perRegimen = mouseStudy.groupby(["Drug Regimen"])

# 2. --> Get values per TUMOR VOLUME 
tumorVolPerReg = perRegimen["Tumor Volume (mm3)"]  # we get a SERIE

# 3. Get statistics  of mean, median, variance, standard deviation, and SEM

meanTumor = tumorVolPerReg.mean()
medianTumor = tumorVolPerReg.median()
varTumor = tumorVolPerReg.var()
stdTumor = tumorVolPerReg.std()
semTumor = tumorVolPerReg.sem()
#meanTumor
#medianTumor
#varTumor
#stdTumor
#semTumor

# 4. Generate a summary statistics table 
tumorVolPerRegSummary = pd.DataFrame({"Mean": meanTumor,"Median": medianTumor,"Variance": varTumor,"Std Dev": stdTumor,"SEM":semTumor})
tumorVolPerRegSummary
# Out:
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar plots

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas

# 1. --> Get values per TUMOR VOLUME 
perRegimenTumorVol = perRegimen["Tumor Volume (mm3)"].count()

# 2. Create a bar chart 
countTumors = perRegimenTumorVol.plot(kind='bar',figsize=(10,5))
countTumors.set_xlabel("Drug Regimen")
countTumors.set_ylabel("Number of Registrations of Tumors Volume(mm3)")

plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot

#1. Create the x-axis values - a LIST
regimen = perRegimenTumorVol.head()
regimenList = list(perRegimenTumorVol.index)

# 2. Tell matplotlib that we will be making a bar chart
plt.bar(regimenList, perRegimenTumorVol, color='b', alpha=0.5, align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in regimenList]
plt.xticks(tick_locations, regimenList, rotation=90)

plt.xlim(-0.75, len(regimenList)-.25)
plt.ylim(0, max(perRegimenTumorVol) + 5)

plt.title("Number of Registrations of Tumors Volume(mm3) per Drug Regime used")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Registrations of Tumors Volume(mm3)")

#plt.figure(figsize=(10,5))
plt.show()

# %% [markdown]
# ## Pie plots

# %%
# A. GET the distribution of Mice per Sex
# 1. --> GROUPBY Sex / Sex is my Index
perSex = mouseStudy.groupby(["Sex"])
#perSex.head()

# %%
# 2. --> Get values per Mouse ID 
countPerSex = perSex["Mouse ID"].count()  # we get a SERIE
countPerSex
# Out:
# Sex
# Female    935
# Male      958
# Name: Mouse ID, dtype: int64

# %%
genderList = countPerSex.keys()
genderList
# Out:
# Index(['Female', 'Male'], dtype='object', name='Sex')

# %%
# 3. --> Get LIST of Sex
perSexType = countPerSex.head()
perSexList = list(perSexType.index)
perSexList
# Out:
# ['Female', 'Male']

# %%
# B.Generate a pie plot using pandas

countSex = countPerSex.plot(kind='pie',title = "Distribution of mice per sex used in the study")
plt.show()
#plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Labels for the sections of our pie chart
#labels = perSexList

# The values of each section of the pie chart
#sizes = countPerSex

# The colors of each section of the pie chart
colors = ["blue", "orange"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0, 0)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(countPerSex, explode=explode, labels=perSexList, colors=colors, autopct="%1.1f%%")
        # autopct --> format for the % value inside each slice


    

plt.title("Distribution of mice per sex used in the study")
# Tells matplotlib that we want a pie chart with equal axes
#plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
#Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. 
####  Find the top most promising treatments
#1. Group by drug/mouseID/TumorSize

drugsGroups = mouseStudy.groupby(["Drug Regimen","Mouse ID","Timepoint"])
#drugsGroups.head()
drugsGroups.count().head(15)
# Out:
#                                  Sex  Age_months  Weight (g)  \
# Drug Regimen Mouse ID Timepoint
# Capomulin    b128     0            1           1           1
#                       5            1           1           1
#                       10           1           1           1
#                       15           1           1           1
#                       20           1           1           1
#                       25           1           1           1
#                       30           1           1           1
#                       35           1           1           1
#                       40           1           1           1
#                       45           1           1           1
#              b742     0            1           1           1
#                       5            1           1           1
#                       10           1           1           1
#                       15           1           1           1
#                       20           1           1           1
#
#                                  Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen Mouse ID Timepoint
# Capomulin    b128     0                           1                 1
#                       5                           1                 1
#                       10                          1                 1
#                       15                          1                 1
#                       20                          1                 1
#                       25                          1                 1
#                       30                          1                 1
#                       35                          1                 1
#                       40                          1                 1
#                       45                          1                 1
#              b742     0                           1                 1
#                       5                           1                 1
#                       10                          1                 1
#                       15                          1                 1
#                       20                          1                 1

# %%
#drugsGroups.dtypes
# Out:
#                                     Sex Age_months Weight (g)  \
# Drug Regimen Mouse ID Timepoint
# Capomulin    b128     0          object      int64      int64
#                       5          object      int64      int64
#                       10         object      int64      int64
#                       15         object      int64      int64
#                       20         object      int64      int64
# ...                                 ...        ...        ...
# Zoniferol    w575     45         object      int64      int64
#              x613     0          object      int64      int64
#                       5          object      int64      int64
#                       10         object      int64      int64
#                       15         object      int64      int64
#
#                                 Tumor Volume (mm3) Metastatic Sites
# Drug Regimen Mouse ID Timepoint
# Capomulin    b128     0                    float64            int64
#                       5                    float64            int64
#                       10                   float64            int64
#                       15                   float64            int64
#                       20                   float64            int64
# ...                                            ...              ...
# Zoniferol    w575     45                   float64            int64
#              x613     0                    float64            int64
#                       5                    float64            int64
#                       10                   float64            int64
#                       15                   float64            int64
#
# [1888 rows x 5 columns]

# %%
# 2. Get variables to use
druglist = mouseStudy["Drug Regimen"].unique()  # antes regimen - is a Serie
print(druglist)

micelist = mouseStudy["Mouse ID"].unique()  #  is a Serie
print(micelist)

timeplist = mouseStudy["Timepoint"].unique()  #  is a Serie
print(timeplist)
# Out:
# ['Ramicane' 'Capomulin' 'Infubinol' 'Placebo' 'Ceftamin' 'Stelasyn'
#  'Zoniferol' 'Ketapril' 'Propriva' 'Naftisol']
# ['k403' 's185' 'x401' 'm601' 'g791' 's508' 'f966' 'm546' 'z578' 'j913'
#  'u364' 'n364' 'y793' 'r554' 'm957' 'c758' 't565' 'a644' 'i177' 'j989'
#  'i738' 'a520' 'w914' 'r811' 'g288' 'i334' 'q610' 'd251' 'l897' 'c458'
#  'b742' 'b128' 'j246' 'a411' 'j119' 'w150' 'v923' 'g316' 's710' 'l509'
#  'r944' 'e662' 'u196' 'q597' 'a444' 'i557' 'r921' 'w678' 'y449' 'a203'
#  'a251' 'a262' 'a275' 'a366' 'a401' 'a457' 'a492' 'a577' 'a685' 'a699'
#  'a788' 'a818' 'a897' 'a963' 'b313' 'b447' 'b487' 'b559' 'b759' 'b879'
#  'c139' 'c264' 'c282' 'c302' 'c326' 'c402' 'c559' 'c580' 'c757' 'c766'
#  'c819' 'c832' 'c895' 'c927' 'd133' 'd164' 'd474' 'e213' 'e227' 'e291'
#  'e476' 'e584' 'f129' 'f234' 'f278' 'f345' 'f394' 'f436' 'f545' 'f932'
#  'f993' 'g107' 'g296' 'g497' 'g558' 'g570' 'g867' 'g989' 'h246' 'h333'
#  'h428' 'h531' 'i386' 'i477' 'i635' 'i669' 'i901' 'j235' 'j296' 'j365'
#  'j755' 'j984' 'k210' 'k382' 'k483' 'k510' 'k603' 'k754' 'k804' 'k862'
#  'k894' 'l215' 'l264' 'l471' 'l490' 'l558' 'l661' 'l700' 'l725' 'l733'
#  'l872' 'm133' 'm269' 'm331' 'm550' 'm650' 'm756' 'n304' 'n482' 'n630'
#  'n671' 'n678' 'n763' 'n923' 'n967' 'o287' 'o302' 'o331' 'o523' 'o562'
#  'o725' 'o795' 'o809' 'o813' 'o848' 'o926' 'o973' 'p136' 'p189' 'p310'
#  'p387' 'p438' 'p981' 'q119' 'q132' 'q483' 'q511' 'q582' 'q633' 'q787'
#  'r107' 'r157' 'r604' 'r701' 'r850' 's121' 's141' 's152' 's166' 's187'
#  's337' 's565' 's619' 't198' 't451' 't573' 't718' 't724' 't994' 'u149'
#  'u153' 'u327' 'u946' 'v199' 'v289' 'v295' 'v339' 'v409' 'v603' 'v719'
#  'v764' 'v766' 'v835' 'v989' 'v991' 'w140' 'w151' 'w167' 'w193' 'w350'
#  'w422' 'w540' 'w575' 'w584' 'w697' 'w746' 'x111' 'x209' 'x226' 'x264'
#  'x336' 'x402' 'x581' 'x613' 'x773' 'x822' 'x930' 'y163' 'y260' 'y478'
#  'y601' 'y769' 'y865' 'z234' 'z314' 'z435' 'z581' 'z795' 'z969']
# [ 0  5 10 15 20 25 30 35 40 45]

# %%
for timepoint in timeplist:
    if x = 0
    print("Tumor Volume (mm3)")
# Out:
#   File "<ipython-input-36-9db8760a109c>", line 2
#     if x = 0
#          ^
# SyntaxError: invalid syntax

# %%
#2. Find difference of size per mouse, per drug by Timepoint (greater value & smaller value )

initialtp = 0
finaltp = 45

for drug in druglist:
    for mouse in mouselist:
        if timepoint = 0 in timeplist:

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. 
# Calculate the IQR and quantitatively determine if there are any potential outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
